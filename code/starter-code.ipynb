# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# **Many folks are questioning the necessity of standardized SAT and ACT tests as a means for preparation and measurement of college readiness in the United States.
# Here, I aim to discover whether there is any correlation between SAT and ACT scores in relation to attainment for a bachelor's degree (graduation rate) at a four-year college in the United States.**
#
# If we find that there is no positive correlation - meaning better test scores = better success rate, it may be time to consider what the purpose of these tests are.
#
# If we find that there is a positive correlation, colleges and universitites may reconsider the current trend of makign these trends optional as a means to acceptance into these institutions.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# In this project, I decided to take a look at whether or not there is a correlation between standardized tests (ACT & SAT) and likelikood to graduate from a four-year college with a Bachelor's degree. If
#
# For this, I needed to bring in some outside data. I sampled data from the US Department of Education's College Scorecard. These datasets are massive and filled with heaps of interesting information!

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`act_2019_ca.csv`](./data/act_2019_ca.csv): 2019 ACT Scores in California by School
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State
# * [`sat_2019_by_intended_college_major.csv`](./data/sat_2019_by_intended_college_major.csv): 2019 SAT Scores by Intended College Major
# * [`sat_2019_ca.csv`](./data/sat_2019_ca.csv): 2019 SAT Scores in California by School
# * [`sat_act_by_college.csv`](./data/sat_act_by_college.csv): Ranges of Accepted ACT & SAT Student Scores by Colleges

# %% [markdown]
# **Chosen Given Datasets:**
#
# `sat_act_by_college.csv:` Ranges of Accepted ACT & SAT Student Scores by Colleges\
# `sat_2017.csv:` 2017 SAT Scores by State\
# `sat_2018.csv:` 2018 SAT Scores by State\
# `sat_2019.csv:` 2019 SAT Scores by State\
# `act_2017.csv:` 2017 ACT Scores by State\
# `act_2018.csv:` 2018 ACT Scores by State\
# `act_2019.csv:` 2019 ACT Scores by State

# %% [markdown]
# ### Outside Research

# %% [markdown]
# Based on your problem statement and your chosen datasets, spend some time doing outside research on state policies or additional information that might be relevant. Summarize your findings below. If you bring in any outside tables or charts, make sure you are explicit about having borrowed them. If you quote any text, make sure that it renders as being quoted. **Make sure that you cite your sources.**

# %% [markdown]
# **Data Sets from US Department of Education College Scorecard**
# URL: https://collegescorecard.ed.gov/data/documentation/
#
# `MERGED2016_17_PP.csv:` 2016-2017 Aggregated data including SAT, ACT scores and college completion rates by college and state.
#
# `MERGED2017_18_PP.csv:` 2017-2018 Aggregated data including SAT, ACT scores and college completion rates by college and state.
#
# `MERGED2018_19_PP.csv:` 2018-2019 Aggregated data including SAT, ACT scores and college completion rates by college and state.

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# This is a function to calculate the mean of a set of values

#test data set:
numbers = [2, 5, 8, 3, 23, 56, 14, 12]

def calc_mean(num):
    # first check for zero values
    if len(num) == 0:
        return 0
    # calculate mean using mean formula
    n = len(num)
    get_sum = sum(num)
    mean = get_sum/n
    return mean

calc_mean(numbers)
# Out:
# 15.375

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# This function calculates standard deviation
num = [2, 5, 8, 3, 23, 56, 14, 12]
    
def calc_std(num):
    # Check for zero values
    if len(num) == 0:
        return 0
    variance = sum([((n - calc_mean(num)) ** 2) for n in num]) / len(num) 
    return variance ** 0.5

calc_std(num)
# Out:
# 16.642847562842125

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
# got help from https://stackoverflow.com/questions/12432663/what-is-a-clean-way-to-convert-a-string-percent-to-a-float
# clean percentage to float and set '-' values to 0.0, "%" to ''
test_data = '29-'

def clean_percent(data):
    for i in data:
        if i == '%':
            return float(data.replace('%', ''))/100
        if i == '-':
            return 0.0

clean_percent(test_data)
# Out:
# 0.0

# %%
#One piece of data has a misplaced x. Wrote a function to clean it

test_x = '29.0x'

def clean_x(data):
    for i in data:
        if i == 'x':
            return float(data.replace('x', ''))
    return float(data)
        
        
clean_x(test_x)
# Out:
# 29.0

# %%
test_data = '29-5'
def clean_dash(data):
    return float(data.replace('-', ''))/100

clean_dash(test_data)
# Out:
# 2.95

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# There was a warning because of my large datasets and suggested the following:
low_memory=False

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
# import data sets
sat_2017 = pd.read_csv('data/sat_2017.csv')
sat_2018 = pd.read_csv('data/sat_2018.csv')
sat_2019 = pd.read_csv('data/sat_2019.csv')
act_2017 = pd.read_csv('data/act_2017.csv')
act_2018 = pd.read_csv('data/act_2018.csv')
act_2019 = pd.read_csv('data/act_2019.csv')
mg_16_17 = pd.read_csv('data/CollegeScorecard_Raw_Data/MERGED2016_17_PP.csv')
mg_17_18 = pd.read_csv('data/CollegeScorecard_Raw_Data/MERGED2017_18_PP.csv')
mg_18_19 = pd.read_csv('data/CollegeScorecard_Raw_Data/MERGED2018_19_PP.csv')
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (6,1729,1909,1910,1911,1912,1913) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# /Applications/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3071: DtypeWarning: Columns (1729) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# ...

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
sat_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2018.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076

# %%
sat_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB

# %%
sat_2019.head()
# Out:
#         State Participation Rate  EBRW  Math  Total
# 0     Alabama                 7%   583   560   1143
# 1      Alaska                41%   556   541   1097
# 2     Arizona                31%   569   565   1134
# 3    Arkansas                 6%   582   559   1141
# 4  California                63%   534   531   1065

# %%
sat_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53 entries, 0 to 52
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   State               53 non-null     object
#  1   Participation Rate  53 non-null     object
#  2   EBRW                53 non-null     int64
#  3   Math                53 non-null     int64
#  4   Total               53 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.2+ KB

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
act_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %%
mg_16_17.head()
# Out:
#    UNITID    OPEID  OPEID6                               INSTNM        CITY  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   STABBR         ZIP  ACCREDAGENCY  INSTURL  NPCURL  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    OMENRUP_PARTTIME_POOLED_SUPP  FTFTPCTPELL  FTFTPCTFLOAN   UG12MN   G12MN  \
# 0                           NaN       0.7373        0.7529   4865.0  1292.0
# ...

# %%
mg_16_17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7238 entries, 0 to 7237
# Columns: 1986 entries, UNITID to SCUGFFN_POOLED
# dtypes: float64(807), int64(12), object(1167)
# memory usage: 109.7+ MB

# %% [markdown]
# **Note to self as I decide how I want to filter**
#
# I want STABBR, ADM_RATE, ADM_RATE_ALL, SATVR25, SATVR75, SATMT25, SATMT75, SATWR25, SATWR75, SATVRMID, SATMTMID, SATWRMID?, SAT_AVG, SAT_AVG_ALL, ACTCM25, ACTCM75, ACTEN25, ACTEN75, ACTMT25, ACTMT75, ACTWR25, ACTWR50, ACTCMMID, ACTENMID, ACTWRMID,
#
# Filter by HIGHDEG 3(for schools that offer bachelor's)
#
# Group by state (STABBR)
#
# P_CREDLEV "Level of credential"
#
# *You'll see that I eventually went with much more stripped down data frames in the end but kept this here so you could see the thought process*

# %%
#25th percentile of SAT scores at the institution (critical reading)
mg_16_17['SATVR25'].head()
# Out:
# 0    380.0
# 1    480.0
# 2      NaN
# 3    520.0
# 4    370.0
# Name: SATVR25, dtype: float64

# %%
# Completion rate for first-time, full-time students at four-year institutions
mg_16_17['C150_4'].head()
# Out:
# 0    0.2749
# 1    0.5309
# 2    0.2500
# 3    0.4867
# 4    0.2165
# Name: C150_4, dtype: float64

# %%
sat_2017.head()
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055

# %%
# function to set title to lowercase
def title_lower(column_title):
    return column_title.columns.str.strip().str.lower()

title_lower(sat_2017)
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
# Help from https://cmdlinetips.com/2020/07/cleaning_up_pandas-column-names/
# Lower titles for sat_2017.columns
sat_2017.columns = title_lower(sat_2017)
sat_2017.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
# Lower titles for sat_2018.columns
sat_2018.columns = title_lower(sat_2018)
sat_2018.columns
# Out:
# Index(['state', 'participation', 'evidence-based reading and writing', 'math',
#        'total'],
#       dtype='object')

# %%
# Lower titles for sat_2019.columns
sat_2019.columns = title_lower(sat_2019)
sat_2019.columns
# Out:
# Index(['state', 'participation rate', 'ebrw', 'math', 'total'], dtype='object')

# %%
# Rename columns to more succnct and readable format
sat_2017_df = sat_2017.rename(columns={"participation" : "part_rate", "evidence-based reading and writing" : "eb_rw"})
sat_2017_df.head()
# Out:
#         state part_rate  eb_rw  math  total
# 0     Alabama        5%    593   572   1165
# 1      Alaska       38%    547   533   1080
# 2     Arizona       30%    563   553   1116
# 3    Arkansas        3%    614   594   1208
# 4  California       53%    531   524   1055

# %%
# Rename columns to more succnct and readable format
sat_2018_df = sat_2018.rename(columns={"participation" : "part_rate", "evidence-based reading and writing" : "eb_rw"})
sat_2018_df.head()
# Out:
#         state part_rate  eb_rw  math  total
# 0     Alabama        6%    595   571   1166
# 1      Alaska       43%    562   544   1106
# 2     Arizona       29%    577   572   1149
# 3    Arkansas        5%    592   576   1169
# 4  California       60%    540   536   1076

# %%
# Rename columns to more succnct and readable format
sat_2019_df = sat_2019.rename(columns={"participation rate" : "part_rate", "ebrw" : "eb_rw"})
sat_2019_df.head()
# Out:
#         state part_rate  eb_rw  math  total
# 0     Alabama        7%    583   560   1143
# 1      Alaska       41%    556   541   1097
# 2     Arizona       31%    569   565   1134
# 3    Arkansas        6%    582   559   1141
# 4  California       63%    534   531   1065

# %%
# .map lambda idea courtesy: https://stackoverflow.com/questions/12604909/pandas-how-to-change-all-the-values-of-a-column
# run clean_percent function on part_rate column
sat_2017_df['part_rate'] = sat_2017_df['part_rate'].map(lambda x: clean_percent(x))

# %%
sat_2017_df.head()
# Out:
#         state  part_rate  eb_rw  math  total
# 0     Alabama       0.05    593   572   1165
# 1      Alaska       0.38    547   533   1080
# 2     Arizona       0.30    563   553   1116
# 3    Arkansas       0.03    614   594   1208
# 4  California       0.53    531   524   1055

# %%
# run clean_percent function on part_rate column
sat_2018_df['part_rate'] = sat_2018_df['part_rate'].map(lambda x: clean_percent(x))

# %%
sat_2018_df.head()
# Out:
#         state  part_rate  eb_rw  math  total
# 0     Alabama       0.06    595   571   1166
# 1      Alaska       0.43    562   544   1106
# 2     Arizona       0.29    577   572   1149
# 3    Arkansas       0.05    592   576   1169
# 4  California       0.60    540   536   1076

# %%
# run clean_percent function on part_rate column
sat_2019_df['part_rate'] = sat_2019_df['part_rate'].map(lambda x: clean_percent(x))

# %%
sat_2019_df['part_rate'].head()
# Out:
# 0    0.07
# 1    0.41
# 2    0.31
# 3    0.06
# 4    0.63
# Name: part_rate, dtype: float64

# %%
# Merge sat_2017 and 2018 dfs
merged_df = pd.merge(sat_2017_df, sat_2018_df, on=['state'])
merged_df.head()
# Out:
#         state  part_rate_x  eb_rw_x  math_x  total_x  part_rate_y  eb_rw_y  \
# 0     Alabama         0.05      593     572     1165         0.06      595
# 1      Alaska         0.38      547     533     1080         0.43      562
# 2     Arizona         0.30      563     553     1116         0.29      577
# 3    Arkansas         0.03      614     594     1208         0.05      592
# 4  California         0.53      531     524     1055         0.60      540
#
#    math_y  total_y
# 0     571     1166
# 1     544     1106
# 2     572     1149
# 3     576     1169
# 4     536     1076

# %%
# # Merge third data set (sat_2018_df) to new Data Frame and calculate mean
# pd.merge(sat_2017_df, sat_2018_df, how='inner', on=['state']).mean()

# %%
#merging all of the provided SAT data sets that were imported
merged_sat_df = pd.merge(merged_df, sat_2019_df, how='inner', on=['state'])
merged_sat_df.head()
# Out:
#         state  part_rate_x  eb_rw_x  math_x  total_x  part_rate_y  eb_rw_y  \
# 0     Alabama         0.05      593     572     1165         0.06      595
# 1      Alaska         0.38      547     533     1080         0.43      562
# 2     Arizona         0.30      563     553     1116         0.29      577
# 3    Arkansas         0.03      614     594     1208         0.05      592
# 4  California         0.53      531     524     1055         0.60      540
#
#    math_y  total_y  part_rate  eb_rw  math  total
# 0     571     1166       0.07    583   560   1143
# 1     544     1106       0.41    556   541   1097
# 2     572     1149       0.31    569   565   1134
# 3     576     1169       0.06    582   559   1141
# 4     536     1076       0.63    534   531   1065

# %%
merged_sat_df.head()
# Out:
#         state  part_rate_x  eb_rw_x  math_x  total_x  part_rate_y  eb_rw_y  \
# 0     Alabama         0.05      593     572     1165         0.06      595
# 1      Alaska         0.38      547     533     1080         0.43      562
# 2     Arizona         0.30      563     553     1116         0.29      577
# 3    Arkansas         0.03      614     594     1208         0.05      592
# 4  California         0.53      531     524     1055         0.60      540
#
#    math_y  total_y  part_rate  eb_rw  math  total
# 0     571     1166       0.07    583   560   1143
# 1     544     1106       0.41    556   541   1097
# 2     572     1149       0.31    569   565   1134
# 3     576     1169       0.06    582   559   1141
# 4     536     1076       0.63    534   531   1065

# %%
# Take mean of participation rates

merged_sat_df['part_rate_mean'] = \
    (merged_sat_df['part_rate_x'] + merged_sat_df['part_rate_y'] + merged_sat_df['part_rate']) / 3

merged_sat_df.head()
# Out:
#         state  part_rate_x  eb_rw_x  math_x  total_x  part_rate_y  eb_rw_y  \
# 0     Alabama         0.05      593     572     1165         0.06      595
# 1      Alaska         0.38      547     533     1080         0.43      562
# 2     Arizona         0.30      563     553     1116         0.29      577
# 3    Arkansas         0.03      614     594     1208         0.05      592
# 4  California         0.53      531     524     1055         0.60      540
#
#    math_y  total_y  part_rate  eb_rw  math  total  part_rate_mean
# 0     571     1166       0.07    583   560   1143        0.060000
# 1     544     1106       0.41    556   541   1097        0.406667
# 2     572     1149       0.31    569   565   1134        0.300000
# 3     576     1169       0.06    582   559   1141        0.046667
# 4     536     1076       0.63    534   531   1065        0.586667

# %%
# Create column for mean of eb_rw (english reading and writing) rates
# Due to the structure of this, I couldn't figure out how to use my calc_mean function
# So I just calculated in a way that worked

merged_sat_df['eb_rw_mean'] = \
    (merged_sat_df['eb_rw_x'] + merged_sat_df['eb_rw_x'] + merged_sat_df['eb_rw']) / 3

merged_sat_df.head()
# Out:
#         state  part_rate_x  eb_rw_x  math_x  total_x  part_rate_y  eb_rw_y  \
# 0     Alabama         0.05      593     572     1165         0.06      595
# 1      Alaska         0.38      547     533     1080         0.43      562
# 2     Arizona         0.30      563     553     1116         0.29      577
# 3    Arkansas         0.03      614     594     1208         0.05      592
# 4  California         0.53      531     524     1055         0.60      540
#
#    math_y  total_y  part_rate  eb_rw  math  total  part_rate_mean  eb_rw_mean
# 0     571     1166       0.07    583   560   1143        0.060000  589.666667
# 1     544     1106       0.41    556   541   1097        0.406667  550.000000
# 2     572     1149       0.31    569   565   1134        0.300000  565.000000
# 3     576     1169       0.06    582   559   1141        0.046667  603.333333
# 4     536     1076       0.63    534   531   1065        0.586667  532.000000

# %%
# Create column for mean of math rates

merged_sat_df['math_mean'] = \
    (merged_sat_df['math_x'] + merged_sat_df['math_y'] + merged_sat_df['math']) / 3

merged_sat_df.head()
# Out:
#         state  part_rate_x  eb_rw_x  math_x  total_x  part_rate_y  eb_rw_y  \
# 0     Alabama         0.05      593     572     1165         0.06      595
# 1      Alaska         0.38      547     533     1080         0.43      562
# 2     Arizona         0.30      563     553     1116         0.29      577
# 3    Arkansas         0.03      614     594     1208         0.05      592
# 4  California         0.53      531     524     1055         0.60      540
#
#    math_y  total_y  part_rate  eb_rw  math  total  part_rate_mean  eb_rw_mean  \
# 0     571     1166       0.07    583   560   1143        0.060000  589.666667
# 1     544     1106       0.41    556   541   1097        0.406667  550.000000
# 2     572     1149       0.31    569   565   1134        0.300000  565.000000
# 3     576     1169       0.06    582   559   1141        0.046667  603.333333
# 4     536     1076       0.63    534   531   1065        0.586667  532.000000
#
#     math_mean
# 0  567.666667
# 1  539.333333
# ...

# %%
# Create column for mean of of totals

merged_sat_df['total_mean'] = \
    (merged_sat_df['total_x'] + merged_sat_df['total_y'] + merged_sat_df['total']) / 3

merged_sat_df.head()
merged_sat_df.to_csv('data/merged_sat_df')

# %%
act_2017.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
# I ran each of these sepearately to make sure they each worked and then put them all in one cell for brevity. 
#This is already a pretty verbose notebook.

#  This is the ACT 2017 data set

# use my title_lower function to lowercase column titles
act_2017.columns = title_lower(act_2017)
# rename 'participation' column
act_2017_df = act_2017.rename(columns={"participation" : "part_rate"})
# Use lambda function utilizing my clean_percent() function to clean percentages on part_rate column
act_2017_df['part_rate'] = act_2017_df['part_rate'].map(lambda x: clean_percent(x))
# Use lambda function utilizing my clean_x() function to clean x from 'composite' column
act_2017_df['composite'] = act_2017_df['composite'].map(lambda x: clean_x(x))
act_2017_df.head()
# Out:
#       state  part_rate  english  math  reading  science  composite
# 0  National       0.60     20.3  20.7     21.4     21.0       21.0
# 1   Alabama       1.00     18.9  18.4     19.7     19.4       19.2
# 2    Alaska       0.65     18.7  19.8     20.4     19.9       19.8
# 3   Arizona       0.62     18.6  19.8     20.1     19.8       19.7
# 4  Arkansas       1.00     18.9  19.0     19.7     19.5       19.4

# %%
# I ran each of these sepearately to make sure they each worked and then put them all in one cell for brevity. 
#This is already a pretty verbose notebook.

#  This is the ACT 2018 data set

# use my title_lower function to lowercase column titles
act_2018.columns = title_lower(act_2018)
# rename 'participation' column
act_2018_df = act_2018.rename(columns={"participation" : "part_rate"})
# Use lambda function utilizing my clean_percent() function to clean percentages on part_rate column
act_2018_df['part_rate'] = act_2018_df['part_rate'].map(lambda x: clean_percent(x))
act_2018_df.head()
# Out:
#         state  part_rate  composite
# 0     Alabama       1.00       19.1
# 1      Alaska       0.33       20.8
# 2     Arizona       0.66       19.2
# 3    Arkansas       1.00       19.4
# 4  California       0.27       22.7

# %%
# I ran each of these sepearately to make sure they each worked and then put them all in one cell for brevity. 
#This is already a pretty verbose notebook.

#  This is the ACT 2019data set

# use my title_lower function to lowercase column titles
act_2019.columns = title_lower(act_2019)
# rename 'participation' column
act_2019_df = act_2019.rename(columns={"participation" : "part_rate"})
# Use lambda function utilizing my clean_percent() function to clean percentages on part_rate column
act_2019_df['part_rate'] = act_2019_df['part_rate'].map(lambda x: clean_percent(x))
act_2019_df.head()
# Out:
#         state  part_rate  composite
# 0     Alabama       1.00       18.9
# 1      Alaska       0.38       20.1
# 2     Arizona       0.73       19.0
# 3    Arkansas       1.00       19.3
# 4  California       0.23       22.6

# %%
# Merge act_2017 and 2018 dfs
merged_act_df = pd.merge(act_2017_df, act_2018_df, how='outer', on=['state'])
merged_act_df.head()
# Out:
#       state  part_rate_x  english  math  reading  science  composite_x  \
# 0  National         0.60     20.3  20.7     21.4     21.0         21.0
# 1   Alabama         1.00     18.9  18.4     19.7     19.4         19.2
# 2    Alaska         0.65     18.7  19.8     20.4     19.9         19.8
# 3   Arizona         0.62     18.6  19.8     20.1     19.8         19.7
# 4  Arkansas         1.00     18.9  19.0     19.7     19.5         19.4
#
#    part_rate_y  composite_y
# 0          NaN          NaN
# 1         1.00         19.1
# 2         0.33         20.8
# 3         0.66         19.2
# 4         1.00         19.4

# %%
# Merge third data set (act_2019_df) to new Data Frame and calculate mean
merged_act_df = pd.merge(merged_act_df, act_2018_df, how='outer', on=['state'])
merged_act_df.head()
# Out:
#       state  part_rate_x  english  math  reading  science  composite_x  \
# 0  National         0.60     20.3  20.7     21.4     21.0         21.0
# 1   Alabama         1.00     18.9  18.4     19.7     19.4         19.2
# 2    Alaska         0.65     18.7  19.8     20.4     19.9         19.8
# 3   Arizona         0.62     18.6  19.8     20.1     19.8         19.7
# 4  Arkansas         1.00     18.9  19.0     19.7     19.5         19.4
#
#    part_rate_y  composite_y  part_rate  composite
# 0          NaN          NaN        NaN        NaN
# 1         1.00         19.1       1.00       19.1
# 2         0.33         20.8       0.33       20.8
# 3         0.66         19.2       0.66       19.2
# 4         1.00         19.4       1.00       19.4

# %%
# Create new column with mean of participation rates

merged_act_df['part_rate_mean'] = \
    (merged_act_df['part_rate_x'] + merged_act_df['part_rate_y'] + merged_act_df['part_rate']) / 3

merged_act_df.head()
# Out:
#       state  part_rate_x  english  math  reading  science  composite_x  \
# 0  National         0.60     20.3  20.7     21.4     21.0         21.0
# 1   Alabama         1.00     18.9  18.4     19.7     19.4         19.2
# 2    Alaska         0.65     18.7  19.8     20.4     19.9         19.8
# 3   Arizona         0.62     18.6  19.8     20.1     19.8         19.7
# 4  Arkansas         1.00     18.9  19.0     19.7     19.5         19.4
#
#    part_rate_y  composite_y  part_rate  composite  part_rate_mean
# 0          NaN          NaN        NaN        NaN             NaN
# 1         1.00         19.1       1.00       19.1        1.000000
# 2         0.33         20.8       0.33       20.8        0.436667
# 3         0.66         19.2       0.66       19.2        0.646667
# 4         1.00         19.4       1.00       19.4        1.000000

# %%
# Create new column with mean of composite scores

merged_act_df['composite_mean'] = \
    (merged_act_df['composite_x'] + merged_act_df['composite_y'] + merged_act_df['composite']) / 3

merged_act_df.head()
# Out:
#       state  part_rate_x  english  math  reading  science  composite_x  \
# 0  National         0.60     20.3  20.7     21.4     21.0         21.0
# 1   Alabama         1.00     18.9  18.4     19.7     19.4         19.2
# 2    Alaska         0.65     18.7  19.8     20.4     19.9         19.8
# 3   Arizona         0.62     18.6  19.8     20.1     19.8         19.7
# 4  Arkansas         1.00     18.9  19.0     19.7     19.5         19.4
#
#    part_rate_y  composite_y  part_rate  composite  part_rate_mean  \
# 0          NaN          NaN        NaN        NaN             NaN
# 1         1.00         19.1       1.00       19.1        1.000000
# 2         0.33         20.8       0.33       20.8        0.436667
# 3         0.66         19.2       0.66       19.2        0.646667
# 4         1.00         19.4       1.00       19.4        1.000000
#
#    composite_mean
# 0             NaN
# 1       19.133333
# 2       20.466667
# 3       19.366667
# 4       19.400000

# %%
# creating new DataFrame with the National row removed as it isn't in any of the other data frames used for this project
merged_act_df = merged_act_df[merged_act_df.state != 'National']
merged_act_df.head()
# Out:
#         state  part_rate_x  english  math  reading  science  composite_x  \
# 1     Alabama         1.00     18.9  18.4     19.7     19.4         19.2
# 2      Alaska         0.65     18.7  19.8     20.4     19.9         19.8
# 3     Arizona         0.62     18.6  19.8     20.1     19.8         19.7
# 4    Arkansas         1.00     18.9  19.0     19.7     19.5         19.4
# 5  California         0.31     22.5  22.7     23.1     22.2         22.8
#
#    part_rate_y  composite_y  part_rate  composite  part_rate_mean  \
# 1         1.00         19.1       1.00       19.1        1.000000
# 2         0.33         20.8       0.33       20.8        0.436667
# 3         0.66         19.2       0.66       19.2        0.646667
# 4         1.00         19.4       1.00       19.4        1.000000
# 5         0.27         22.7       0.27       22.7        0.283333
#
#    composite_mean
# 1       19.133333
# 2       20.466667
# 3       19.366667
# 4       19.400000
# 5       22.733333

# %%
# Export csv of merged act data to data/ dir
merged_act_df.to_csv('data/merged_act_df')

# %%
# Lower titles for mg_16_17 columns
# mg_16_17 is the data set from USDE for 2016-2017 school year
mg_16_17.columns = title_lower(mg_16_17)
mg_16_17.head()
# Out:
#    unitid    opeid  opeid6                               instnm        city  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   stabbr         zip  accredagency  insturl  npcurl  ...  \
# 0     AL       35762           NaN      NaN     NaN  ...
# 1     AL  35294-0110           NaN      NaN     NaN  ...
# 2     AL  36117-3553           NaN      NaN     NaN  ...
# 3     AL       35899           NaN      NaN     NaN  ...
# 4     AL  36104-0271           NaN      NaN     NaN  ...
#
#    omenrup_parttime_pooled_supp  ftftpctpell  ftftpctfloan   ug12mn   g12mn  \
# 0                           NaN       0.7373        0.7529   4865.0  1292.0
# ...

# %%
#renaming column names
mg_16_17_df = mg_16_17.rename(columns={
    "stabbr" : "state", 
    "satvrmid" : "sat_vr_mid", 
    "satwrmid" : "sat_wr_mid",
    "satmtmid" : "sat_mt_mid",
    "actcmmid": "act_cm_mid",
    "actenmid": "act_en_mid",
    "actmtmid": "act_mt_mid",
    "highdeg" : "deg_type",
    "p_credlev" : "p_cred_lev",
    "c200_4" : "grad_rate"
})
mg_16_17_df.head()
# Out:
#    unitid    opeid  opeid6                               instnm        city  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   state         zip  accredagency  insturl  npcurl  ...  \
# 0    AL       35762           NaN      NaN     NaN  ...
# 1    AL  35294-0110           NaN      NaN     NaN  ...
# 2    AL  36117-3553           NaN      NaN     NaN  ...
# 3    AL       35899           NaN      NaN     NaN  ...
# 4    AL  36104-0271           NaN      NaN     NaN  ...
#
#    omenrup_parttime_pooled_supp  ftftpctpell  ftftpctfloan   ug12mn   g12mn  \
# 0                           NaN       0.7373        0.7529   4865.0  1292.0
# ...

# %%
# help from https://stackoverflow.com/questions/34682828/extracting-specific-selected-columns-to-new-dataframe-as-a-copy
# Since there are nearly 2,000 columns, filtering in the columns wanted
# de = department of education
de_16_17_df = mg_16_17_df.filter(["state", "sat_vr_mid", "sat_wr_mid", "sat_mt_mid", "act_cm_mid", "act_en_mid", "act_mt_mid", "sat_avg", "sat_avg_all", "deg_type", "grad_rate"])
de_16_17_df
# Out:
#      state  sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  \
# 0       AL       425.0         NaN       420.0        18.0        17.0
# 1       AL       560.0         NaN       575.0        25.0        26.0
# 2       AL         NaN         NaN         NaN         NaN         NaN
# 3       AL       590.0         NaN       610.0        28.0        29.0
# 4       AL       415.0         NaN       410.0        17.0        17.0
# ...    ...         ...         ...         ...         ...         ...
# 7233    PA         NaN         NaN         NaN         NaN         NaN
# 7234    CA         NaN         NaN         NaN         NaN         NaN
# 7235    CA         NaN         NaN         NaN         NaN         NaN
# 7236    TX         NaN         NaN         NaN         NaN         NaN
# 7237    MA         NaN         NaN         NaN         NaN         NaN
#
#       act_mt_mid  sat_avg  sat_avg_all  deg_type  grad_rate
# ...

# %%
# filtering all colleges that don't offer bachelors degrees deg_type 3 = bachelor's 
de_16_17_df = de_16_17_df[de_16_17_df.deg_type == 3]
de_16_17_df
# Out:
#      state  sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  \
# 7       AL         NaN         NaN         NaN         NaN         NaN
# 10      AL       555.0         NaN       530.0        26.0        26.0
# 12      AL         NaN         NaN         NaN         NaN         NaN
# 23      AL       473.0         NaN       475.0        22.0        21.0
# 31      AL       581.0         NaN       531.0        22.0        22.0
# ...    ...         ...         ...         ...         ...         ...
# 6719    NY         NaN         NaN         NaN         NaN         NaN
# 6727    IL         NaN         NaN         NaN         NaN         NaN
# 6748    NJ         NaN         NaN         NaN         NaN         NaN
# 6750    FL         NaN         NaN         NaN         NaN         NaN
# 6774    CO         NaN         NaN         NaN         NaN         NaN
#
#       act_mt_mid  sat_avg  sat_avg_all  deg_type  grad_rate
# ...

# %%
# Group data by state and mean values
mean_de_16_17_df = de_16_17_df.groupby(['state']).mean()
mean_de_16_17_df.head()
# Out:
#        sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  act_mt_mid  \
# state
# AK            NaN         NaN         NaN         NaN         NaN         NaN
# AL         503.50         NaN      489.00        21.4        20.8        19.2
# AR         480.25         NaN      500.75        22.8        22.6        21.8
# AS            NaN         NaN         NaN         NaN         NaN         NaN
# AZ         474.00         NaN      500.00        20.0        18.0        20.0
#
#        sat_avg  sat_avg_all  deg_type  grad_rate
# state
# AK         NaN          NaN         3        NaN
# AL       979.8        979.8         3   0.389950
# AR      1040.4       1040.4         3   0.376578
# AS         NaN          NaN         3        NaN
# AZ       963.0       1021.0         3   0.374143

# %%
#renaming column names
mg_17_18.columns = title_lower(mg_17_18)
mg_17_18_df = mg_17_18.rename(columns={
    "stabbr" : "state", 
    "satvrmid" : "sat_vr_mid", 
    "satwrmid" : "sat_wr_mid",
    "satmtmid" : "sat_mt_mid",
    "actcmmid": "act_cm_mid",
    "actenmid": "act_en_mid",
    "actmtmid": "act_mt_mid",
    "highdeg" : "deg_type",
    "p_credlev" : "p_cred_lev",
    "c200_4" : "grad_rate"
})
mg_17_18_df.head()
# Out:
#    unitid    opeid  opeid6                               instnm        city  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   state         zip  accredagency  insturl  npcurl  ...  \
# 0    AL       35762           NaN      NaN     NaN  ...
# 1    AL  35294-0110           NaN      NaN     NaN  ...
# 2    AL  36117-3553           NaN      NaN     NaN  ...
# 3    AL       35899           NaN      NaN     NaN  ...
# 4    AL  36104-0271           NaN      NaN     NaN  ...
#
#    omenrup_parttime_pooled_supp  ftftpctpell  ftftpctfloan   ug12mn   g12mn  \
# 0                           NaN       0.7106        0.7418   5207.0  1185.0
# ...

# %%
# Since there are nearly 2,000 columns, filtering in the columns wanted
de_17_18_df = mg_17_18_df.filter(["state", "sat_vr_mid", "sat_wr_mid", "sat_mt_mid", "act_cm_mid", "act_en_mid", "act_mt_mid", "sat_avg", "sat_avg_all", "deg_type", "grad_rate"])
de_17_18_df.shape
# Out:
# (7112, 11)

# %%
# filtering all colleges that don't offer bachelors degrees deg_type 3 = bachelor's 
# I later learned to do this inline with the filtering but I'll leave this here
de_17_18_df = de_17_18_df[de_17_18_df.deg_type == 3]
de_17_18_df
# Out:
#      state  sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  \
# 7       AL         NaN         NaN         NaN         NaN         NaN
# 10      AL       575.0         NaN       570.0        26.0        27.0
# 12      AL         NaN         NaN         NaN         NaN         NaN
# 23      AL       543.0         NaN       540.0        22.0        21.0
# 31      AL         NaN         NaN         NaN        22.0        22.0
# ...    ...         ...         ...         ...         ...         ...
# 6631    NY         NaN         NaN         NaN         NaN         NaN
# 6632    NJ         NaN         NaN         NaN         NaN         NaN
# 6647    WI         NaN         NaN         NaN         NaN         NaN
# 6652    NY         NaN         NaN         NaN         NaN         NaN
# 6664    WI         NaN         NaN         NaN         NaN         NaN
#
#       act_mt_mid  sat_avg  sat_avg_all  deg_type  grad_rate
# ...

# %%
# grouping by state
mean_de_17_18_df = de_17_18_df.groupby(['state']).mean()
mean_de_17_18_df.head()
# Out:
#        sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  act_mt_mid  \
# state
# AK            NaN         NaN         NaN         NaN         NaN         NaN
# AL          559.0         NaN      555.00   23.333333   23.333333        22.0
# AR          541.0         NaN      538.25   22.200000   22.400000        21.8
# AS            NaN         NaN         NaN         NaN         NaN         NaN
# AZ          485.0         NaN      480.00   18.000000   17.000000        18.0
#
#            sat_avg  sat_avg_all  deg_type  grad_rate
# state
# AK             NaN          NaN         3        NaN
# AL     1133.666667  1133.666667         3   0.280844
# AR     1098.400000  1098.400000         3   0.366887
# AS             NaN          NaN         3        NaN
# AZ      956.000000   956.000000         3   0.415380

# %%
#renaming column names
mg_18_19.columns = title_lower(mg_18_19)
mg_18_19_df = mg_18_19.rename(columns={
    "stabbr" : "state", 
    "satvrmid" : "sat_vr_mid", 
    "satwrmid" : "sat_wr_mid",
    "satmtmid" : "sat_mt_mid",
    "actcmmid": "act_cm_mid",
    "actenmid": "act_en_mid",
    "actmtmid": "act_mt_mid",
    "highdeg" : "deg_type",
    "p_credlev" : "p_cred_lev",
    "c200_4" : "grad_rate"
})
mg_18_19_df.head()
# Out:
#    unitid    opeid  opeid6                               instnm        city  \
# 0  100654   100200    1002             Alabama A & M University      Normal
# 1  100663   105200    1052  University of Alabama at Birmingham  Birmingham
# 2  100690  2503400   25034                   Amridge University  Montgomery
# 3  100706   105500    1055  University of Alabama in Huntsville  Huntsville
# 4  100724   100500    1005             Alabama State University  Montgomery
#
#   state         zip                                       accredagency  \
# 0    AL       35762  Southern Association of Colleges and Schools C...
# 1    AL  35294-0110  Southern Association of Colleges and Schools C...
# 2    AL  36117-3553  Southern Association of Colleges and Schools C...
# 3    AL       35899  Southern Association of Colleges and Schools C...
# 4    AL  36104-0271  Southern Association of Colleges and Schools C...
#
#                      insturl  \
# 0              www.aamu.edu/
# ...

# %%
# Since there are nearly 2,000 columns, filtering in the columns wanted
de_18_19_df = mg_18_19_df.filter(["state", "sat_vr_mid", "sat_wr_mid", "sat_mt_mid", "act_cm_mid", "act_en_mid", "act_mt_mid", "sat_avg", "sat_avg_all", "deg_type", "grad_rate"])
de_18_19_df
# Out:
#      state  sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  \
# 0       AL       475.0         NaN       465.0        18.0        17.0
# 1       AL       555.0         NaN       555.0        25.0        27.0
# 2       AL         NaN         NaN         NaN         NaN         NaN
# 3       AL       630.0         NaN       565.0        28.0        30.0
# 4       AL       480.0         NaN       465.0        18.0        17.0
# ...    ...         ...         ...         ...         ...         ...
# 6801    GA         NaN         NaN         NaN         NaN         NaN
# 6802    GA         NaN         NaN         NaN         NaN         NaN
# 6803    KY         NaN         NaN         NaN         NaN         NaN
# 6804    FL         NaN         NaN         NaN         NaN         NaN
# 6805    CA         NaN         NaN         NaN         NaN         NaN
#
#       act_mt_mid  sat_avg  sat_avg_all  deg_type  grad_rate
# ...

# %%
# filtering all colleges that don't offer bachelors degrees deg_type 3 = bachelor's 
de_18_19_df = de_18_19_df[de_18_19_df.deg_type == 3]
de_18_19_df
# Out:
#      state  sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  \
# 10      AL       570.0         NaN       560.0        26.0        27.0
# 22      AL       540.0         NaN       534.0        22.0        21.0
# 29      AL       568.0         NaN       530.0        20.0        21.0
# 34      AL         NaN         NaN         NaN         NaN         NaN
# 49      AL         NaN         NaN         NaN         NaN         NaN
# ...    ...         ...         ...         ...         ...         ...
# 6263    MD         NaN         NaN         NaN         NaN         NaN
# 6271    NJ         NaN         NaN         NaN         NaN         NaN
# 6299    AR         NaN         NaN         NaN         NaN         NaN
# 6319    MO         NaN         NaN         NaN         NaN         NaN
# 6322    IN         NaN         NaN         NaN         NaN         NaN
#
#       act_mt_mid  sat_avg  sat_avg_all  deg_type  grad_rate
# ...

# %%
# Group by state and calc mean
mean_de_18_19_df = de_18_19_df = de_18_19_df.groupby(['state']).mean()
mean_de_18_19_df.head()
# Out:
#        sat_vr_mid  sat_wr_mid  sat_mt_mid  act_cm_mid  act_en_mid  act_mt_mid  \
# state
# AK            NaN         NaN         NaN         NaN         NaN         NaN
# AL     559.333333         NaN  541.333333   22.666667        23.0   20.666667
# AR     536.000000         NaN  522.500000   22.250000        22.5   21.750000
# AS            NaN         NaN         NaN         NaN         NaN         NaN
# AZ     510.000000         NaN  518.000000   20.000000        19.0   19.000000
#
#            sat_avg  sat_avg_all  deg_type  grad_rate
# state
# AK             NaN          NaN         3   0.100000
# AL     1128.666667  1128.666667         3   0.378467
# AR     1106.500000  1106.500000         3   0.383087
# AS             NaN          NaN         3        NaN
# AZ     1032.000000  1032.000000         3   0.589050

# %%
# Group by state and calc mean
merged_de_df = pd.merge(mean_de_16_17_df, mean_de_17_18_df, on=['state'])
merged_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  \
# state
# AK              NaN        NaN            NaN           3          NaN
# AL             19.2      979.8          979.8           3     0.389950
# AR             21.8     1040.4         1040.4           3     0.376578
# AS              NaN        NaN            NaN           3          NaN
# AZ             20.0      963.0         1021.0           3     0.374143
#
# ...

# %%
# Group by state and calc mean
# Sanity check shape
merged_mean_de_df = pd.merge(merged_de_df, mean_de_18_19_df, on=['state'])
merged_mean_de_df.shape
# Out:
# (50, 30)

# %%
# Create column with mean of SAT verbal mid rates

merged_mean_de_df['sat_vr_mid_mean'] = \
    (merged_mean_de_df['sat_vr_mid_x'] + merged_mean_de_df['sat_vr_mid_y'] + merged_mean_de_df['sat_vr_mid']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Create column with mean of SAT writing mid rates

merged_mean_de_df['sat_wr_mid_mean'] = \
    (merged_mean_de_df['sat_wr_mid_x'] + merged_mean_de_df['sat_wr_mid_y'] + merged_mean_de_df['sat_wr_mid']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Take mean of SAT math mid rates

merged_mean_de_df['sat_mt_mid_mean'] = \
    (merged_mean_de_df['sat_mt_mid_x'] + merged_mean_de_df['sat_mt_mid_y'] + merged_mean_de_df['sat_mt_mid']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Create column with mean of ACT comprehension mid rates

merged_mean_de_df['act_cm_mid_mean'] = \
    (merged_mean_de_df['act_cm_mid_x'] + merged_mean_de_df['act_cm_mid_y'] + merged_mean_de_df['act_cm_mid']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Create column with mean of ACT english mid rates

merged_mean_de_df['act_en_mid_mean'] = \
    (merged_mean_de_df['act_en_mid_x'] + merged_mean_de_df['act_en_mid_y'] + merged_mean_de_df['act_en_mid']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Create column with mean of ACT math mid rates

merged_mean_de_df['act_mt_mid_mean'] = \
    (merged_mean_de_df['act_mt_mid_x'] + merged_mean_de_df['act_mt_mid_y'] + merged_mean_de_df['act_mt_mid']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Create column with mean of SAT average rates

merged_mean_de_df['sat_avg_mean'] = \
    (merged_mean_de_df['sat_avg_x'] + merged_mean_de_df['sat_avg_y'] + merged_mean_de_df['sat_avg']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Create column with mean of ACT cm mid rates

merged_mean_de_df['grad_rate_mean'] = \
    (merged_mean_de_df['grad_rate_x'] + merged_mean_de_df['grad_rate_y'] + merged_mean_de_df['grad_rate']) / 3

merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3     0.389950  ...
# AR             21.8     1040.4         1040.4           3     0.376578  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Create column with mean of all act scores and round to the tenth
merged_mean_de_df['act_avg_mean'] = \
    (merged_mean_de_df['act_cm_mid_mean'] + merged_mean_de_df['act_en_mid_mean'] + merged_mean_de_df['act_mt_mid_mean']) / 3

merged_mean_de_df = merged_mean_de_df.round(2)
merged_mean_de_df.head()
# Out:
#        sat_vr_mid_x  sat_wr_mid_x  sat_mt_mid_x  act_cm_mid_x  act_en_mid_x  \
# state
# AK              NaN           NaN           NaN           NaN           NaN
# AL           503.50           NaN        489.00          21.4          20.8
# AR           480.25           NaN        500.75          22.8          22.6
# AS              NaN           NaN           NaN           NaN           NaN
# AZ           474.00           NaN        500.00          20.0          18.0
#
#        act_mt_mid_x  sat_avg_x  sat_avg_all_x  deg_type_x  grad_rate_x  ...  \
# state                                                                   ...
# AK              NaN        NaN            NaN           3          NaN  ...
# AL             19.2      979.8          979.8           3         0.39  ...
# AR             21.8     1040.4         1040.4           3         0.38  ...
# AS              NaN        NaN            NaN           3          NaN  ...
# ...

# %%
# Filter data further to get just averages of data I want
new_merged_mean_de_df = merged_mean_de_df.filter(["state", "act_avg_mean", "sat_avg_mean", "grad_rate_mean"])
new_merged_mean_de_df.head()
# Out:
#        act_avg_mean  sat_avg_mean  grad_rate_mean
# state
# AK              NaN           NaN             NaN
# AL            21.82       1080.71            0.35
# AR            22.23       1081.77            0.38
# AS              NaN           NaN             NaN
# AZ            18.78        983.67            0.46

# %%
# Create df with grad_rate removed
test_means = new_merged_mean_de_df.filter(['act_avg_mean', 'sat_avg_mean'])
test_means.head()
# Out:
#        act_avg_mean  sat_avg_mean
# state
# AK              NaN           NaN
# AL            21.82       1080.71
# AR            22.23       1081.77
# AS              NaN           NaN
# AZ            18.78        983.67

# %%
# Find max of column 'act_avg_mean'
new_merged_mean_de_df['act_avg_mean'].max()
# Out:
# 30.33

# %%
# Find min of column 'act_avg_mean'
new_merged_mean_de_df['act_avg_mean'].min()
# Out:
# 18.17

# %%
# Find max of column 'sat_avg_mean'
new_merged_mean_de_df['sat_avg_mean'].max()
# Out:
# 1343.67

# %%
# Find min of column 'sat_avg_mean'
new_merged_mean_de_df['sat_avg_mean'].min()
# Out:
# 962.83

# %%
# Testing out data normalization
# Didn't actually use this
normalized_de_df=(new_merged_mean_de_df-new_merged_mean_de_df.min())/(new_merged_mean_de_df.max()-new_merged_mean_de_df.min())
normalized_de_df.head()
# Out:
#        act_avg_mean  sat_avg_mean  grad_rate_mean
# state
# AK              NaN           NaN             NaN
# AL         0.300164      0.309526        0.350877
# AR         0.333882      0.312310        0.403509
# AS              NaN           NaN             NaN
# AZ         0.050164      0.054721        0.543860

# %% [markdown]
# # New Data Frames from cleaned and merged data frames

# %% [markdown]
# `merged_act_df.csv` - cleaned and merged data with mean columns from the provided ACT data sets
# `merged_sat_df.csv` - cleaned and merged data with mean columns from the provided SAT data sets
# `merged_mean_de_df.csv` - cleaned and merged data with mean columns from multiple data sets from US dept. of education.

# %% [markdown]
# ### Data Dictionary
#
# Much of this data dictionary gleaned and adapted from included data.yaml file for US Department of Education College Report Card
#
# Data URL: https://collegescorecard.ed.gov/data/documentation/
#
# File located in dir data/CollegeScorecard_Raw_Data/'data.yaml'
#
# It can be provided upon request
# Can also be found in the data download from the provided url for the DECSC data set
#
# The following data definitions are the column names used for visualizations and presentation and include the edited and formatted names that differ from the original data sources. All else are excluded as they were not used for the analysis and presentation.
#
# Key:
#
#     source: column name
#     type: data type
#     description: description
#
#
#     source: state
#     description: State postcode
#
#     source: sat_avg
#     type: float
#     description: Average SAT equivalent score of students admitted
#
#     source: satvrmid
#     type: float
#     description: Midpoint of SAT scores at the institution (critical reading)
#
#     source: satmtmid
#     type: float
#     description: Midpoint of SAT scores at the institution (math)
#
#     source: satwrmid
#     type: float
#     description: Midpoint of SAT scores at the institution (writing)
#
#     source: actcmmid
#     type: float
#     description: Midpoint of the ACT cumulative score
#
#     source: actenmid
#     type: float
#     description: Midpoint of the ACT English score
#
#     source: actmtmid
#     type: float
#     description: Midpoint of the ACT math score
#
#     source: ACTMIDWR
#     type: float
#     description: Midpoint of the ACT writing score
#
#     source: act_avg
#     type: float
#     description: Average SAT equivalent score of students admitted
#
#     source: deg_type
#     type: integer
#     description: |-
#       Highest degree awarded
#        0 Non-degree-granting
#        1 Certificate degree
#        2 Associate degree
#        3 Bachelor's degree
#        4 Graduate degree
#
#     source: grad_rate
#     type: float
#     description: Completion rate for first-time, full-time bachelor's-degree-seeking
#       students at four-year institutions (200% of expected time to completion)
#
#     source: p_cred_lev
#     type: integer
#     map: program
#     descripton: "Level of credential
#       Credentials are categorized into the following levels:
#       1: Undergraduate Certificate or Diploma
#       2: Associate's Degree
#       3: Bachelor's Degree
#       4: Post-baccalaureate Certificate
#       5: Master's Degree
#       6: Doctoral Degree
#       7: First Professional Degree
#       8: Graduate/Professional Certificate"
#
# ## Functions:
#
# Functions aren't typically part of a data dictionary but it's nice to have a quick reference
#
# source: calc_mean
# variables: takes data set (num)
# description: a function to check for zero values, then calculate the mean of a set of values
#
# source: calc_std
# variables: takes data set (num)
# description: a function to check for zero values, then calculate the standard deviation of a set of values
#
# source: clean_percent
# variables: takes a string (data)
# description: a function to check for '%' value and removes them using data.replace
#
# source: clean_x
# variables: takes a string (data)
# description: a function to check for 'x' value and removes them using data.replace
#
# source: clean_dash
# variables: takes a string (data)
# description: a function to check for '-' value and removes them using data.replace
#
# source: title_lower
# variables: takes a string (column_title)
# description: a function to convert capital letters to lowercase

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
# grabbing an earlier dataset for running standard deviation
# Drop na values and filter by four-year colleges offering bachelor's degrees
std_cols = de_16_17_df[de_16_17_df.deg_type == 3].filter(['sat_avg', 'act_cm_mid', 'act_en_mid', 'act_mt_mid', 'grad_rate']).dropna()
std_cols
# Out:
#       sat_avg  act_cm_mid  act_en_mid  act_mt_mid  grad_rate
# 10     1150.0        26.0        26.0        24.0     0.6489
# 23     1001.0        22.0        21.0        20.0     0.4625
# 31     1013.0        22.0        22.0        20.0     0.4421
# 53      970.0        21.0        19.0        17.0     0.1538
# 54      765.0        16.0        16.0        15.0     0.2192
# ...       ...         ...         ...         ...        ...
# 4164   1263.0        29.0        29.0        26.0     0.6937
# 4461    999.0        21.0        22.0        21.0     0.3636
# 5074   1490.0        34.0        35.0        34.0     0.9600
# 5443    994.0        22.0        23.0        21.0     0.0000
# 5598   1180.0        26.0        28.0        25.0     0.5294
#
# [189 rows x 5 columns]

# %%
# Find Max of column 'sat_avg'
std_cols['sat_avg'].max()
# Out:
# 1496.0

# %%
# Find Max of column 'sat_avg'
std_cols['sat_avg'].min()
# Out:
# 712.0

# %%
# Create dictionary comprehension apply the standard deviation function 
sd = {column: calc_std(std_cols[column]) for column in (std_cols)}
print(sd)
# Out:
# {'sat_avg': 160.1175123459678, 'act_cm_mid': 4.120983291567874, 'act_en_mid': 4.8720592618775855, 'act_mt_mid': 4.0125639028199975, 'grad_rate': 0.2210420707172255}

# %%
# More thought process code the next few rows playing with similar idea as the sd assignment
# Utilizing bins for visulization
# Would normally drop all of this but keeping for instructors to see

bins = np.linspace(700, 1500, 10)
digitized = np.digitize(std_cols['sat_avg'], bins)
    
std_cols['bin_num'] = digitized
print(std_cols)
# Out:
#       sat_avg  act_cm_mid  act_en_mid  act_mt_mid  grad_rate  bin_num
# 10     1150.0        26.0        26.0        24.0     0.6489        6
# 23     1001.0        22.0        21.0        20.0     0.4625        4
# 31     1013.0        22.0        22.0        20.0     0.4421        4
# 53      970.0        21.0        19.0        17.0     0.1538        4
# 54      765.0        16.0        16.0        15.0     0.2192        1
# ...       ...         ...         ...         ...        ...      ...
# 4164   1263.0        29.0        29.0        26.0     0.6937        7
# 4461    999.0        21.0        22.0        21.0     0.3636        4
# 5074   1490.0        34.0        35.0        34.0     0.9600        9
# 5443    994.0        22.0        23.0        21.0     0.0000        4
# 5598   1180.0        26.0        28.0        25.0     0.5294        6
#
# [189 rows x 6 columns]

# %%
sd_sat = {bin_num: calc_std(std_cols[std_cols.bin_num == bin_num]['sat_avg']) for bin_num in range(std_cols['bin_num'].max())}
print(sd)
# Out:
# {'sat_avg': 160.1175123459678, 'act_cm_mid': 4.120983291567874, 'act_en_mid': 4.8720592618775855, 'act_mt_mid': 4.0125639028199975, 'grad_rate': 0.2210420707172255}

# %%
# # using existing functions created above: calc_mean and calc_std - create dictionary comprehension:
# # Holy crap this took me a while but I figured it out by myself! ヽ(°〇°)ﾉ

de_16_17_df[de_16_17_df.deg_type == 3]

sd_bins = {bin_num: calc_std(std_cols[std_cols.bin_num == bin_num]['sat_avg']) for bin_num in range(std_cols['bin_num'].max())}
print(sd)
# Out:
# {'sat_avg': 160.1175123459678, 'act_cm_mid': 4.120983291567874, 'act_en_mid': 4.8720592618775855, 'act_mt_mid': 4.0125639028199975, 'grad_rate': 0.2210420707172255}

# %%
sd_mean = {bin_num: calc_mean(std_cols[std_cols.bin_num == bin_num]['sat_avg']) for bin_num in range(std_cols['bin_num'].max())}
print(sd_mean)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-105-f7efd547f460> in <module>
#       1 sd_mean = {bin_num: calc_mean(std_cols[std_cols.bin_num == bin_num]['sat_avg']) for bin_num in range(std_cols['bin_num'].max())}
# ----> 2 print(sd_mean[sd_mean])
#
# TypeError: unhashable type: 'dict'

# %%
# def calc_std(column, table):
#     variance = [(x-calc_mean(table[column]))**2 for n in table[column]]
#     return variance ** 0.5

# sd = [std_cols(x, new_merged_mean_de_df) for x in new_merged_mean_de_df.columns[1:]]
# calc_mean(sd)

# %% [markdown]
# **To-Do:** *Edit this cell with your findings on trends in the data (step 3 above).*

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
#ACT scores as they relate to graduation rate
g = sns.catplot(x="act_avg_mean", y="grad_rate_mean", kind="bar", data=new_merged_mean_de_df, aspect=2)
g.set(xlim=(18.0, 31.0), ylim=(0,0.7))
g.set_axis_labels("ACT average score","Graduation Rate")
g.set_xticklabels(rotation=45)
plt.title("Correlation between ACT scores and graduation rate");
plt.savefig("ACT.png", transparent=False)

# %% [markdown]
# **There appears to be some positive correlation between higher ACT test scores and higher likelihood to graduate with a bachelor's degree from a four-year college**

# %%
#ACT scores as they relate to graduation rate
g = sns.catplot(x="sat_avg_mean", y="grad_rate_mean", kind="bar", data=new_merged_mean_de_df, aspect=2)
g.set(xlim=(0, 10), ylim=(0,0.8))
g.set_axis_labels("SAT average score","Graduation Rate")
g.set_xticklabels(rotation=45)
plt.title("Correlation between SAT scores and graduation rate");
plt.savefig("SAT.png", transparent=False)

# %% [markdown]
# **There appears to be some positive correlation between higher SAT test scores and higher likelihood to graduate with a bachelor's degree from a four-year college**

# %%
# I did do a lot of trying various different things but doesn't look great.
# uniform_data = new_merged_mean_de_df
# ax = sns.heatmap(uniform_data, center=100, linewidths=.5)


# After an ugly attempt with the commented code above, tried the below:
# Found this example here: https://stackoverflow.com/questions/39409866/correlation-heatmap

Var_Corr = std_cols.corr()
sns.color_palette("cubehelix", as_cmap=True)
sns.heatmap(Var_Corr, xticklabels=Var_Corr.columns, yticklabels=Var_Corr.columns, annot=True)
plt.title("Correlation between SAT scores and graduation rate");

# %%
# visualize same data using plots
ax = sns.regplot(x="act_avg_mean", y="grad_rate_mean", data=new_merged_mean_de_df, x_jitter=.1, marker="+", color="m")
plt.title("Correlation between ACT scores and graduation rate")
g.set_axis_labels("ACT average score","Graduation Rate");

# %%
# visualize same data using plots
ax = sns.regplot(x="sat_avg_mean", y="grad_rate_mean", data=new_merged_mean_de_df, x_jitter=.1, marker="+", color="m")
plt.title("Correlation between SAT scores and graduation rate")
g.set_axis_labels("SAT average score","Graduation Rate");

# %%
# Definitely could use some more practice with histograms with these types of datasets.
# Got a bit frustrated with lack of options to manipulate the graph's appearance and titles.
sns.histplot(data=sd_bins, x=sd_bins, kde=True)

# %%
# Hmmm alright. Well, this is a tough one. Tried to get the bins set but that doesn't
# seem to work with this style. It's a bunch of rubbish. There is a positive trend though, 
# so there's that. Spent an hour or so trying to get this happier and moved on. 

sns.set_theme(style="ticks", palette="cubehelix")

g = sns.boxplot(
    x="sat_avg", 
    y="grad_rate", 
    palette=["magenta", "cyan"],
    data=std_cols,
    width=10.0)
sns.despine(offset=10, trim=True)
g = sns.swarmplot(x="sat_avg", y="grad_rate", data=std_cols, color=".25")
# Out:
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /Applications/anaconda3/lib/python3.8/site-packages/seaborn/categorical.py:1296: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# **So, do the SAT and/or ACT scores predict likelihood to succeed (graduate with bachelor's degree) in a four-year college?**
#
# Looking at the data, it appears that both the ACT and SAT seem to have positive correlations in predicting college success. SAT test data appears to be more telling of future college success. But the correlation isn't super strong on either test set to the point that I would rule one way or another to keeping or gettig rid of these tests in relation to preperation and acceptance into colleges.
#
# On a personal note - as someone who struggles with severe test anxiety - I feel that tests like these test one's ability to take tests well. Which I suppose is a skill needed in college so it's not surprising that there is some apparent correlation.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
